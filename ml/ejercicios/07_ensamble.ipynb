# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/juansensio/elcursodeia-code/blob/master/ml/ejercicios/07_ensamble.ipynb)

# %% [markdown]
# # Ejercicio: Experimenta con modelos ensamblados y el dataset MNIST

# %% [markdown]
# ## 1. Prepara los datos
#
# Carga los datos MNIST y divídelos en un conjunto de entrenamiento, un conjunto de validación y un conjunto de prueba (por ejemplo, usa 50,000 instancias para entrenamiento, 10,000 para validación y 10,000 para pruebas).

# %%
from sklearn.datasets import fetch_openml
import numpy as np

# tu código aquí

# %% [markdown]
# ## 2. Entrena varios clasificadores
#
# Entrena varios clasificadores, como un clasificador Random Forest, un clasificador Extra-Trees y un SVM.
#
# > Extra-Trees es una técnica para hacer que Random Forest sea más aleatorio al usar umbrales aleatorios para cada característica en lugar de buscar el mejor. Son mucho más rápidos de entrenar ya que encontrar el mejor umbral es la operación más costosa en Random Forests.

# %%
# tu código aquí

# %% [markdown]
# ## 3. Combina los métodos
#
# A continuación, intenta combinarlos en un ensamblado que supere a todos los modelos por separado en el conjunto de validación, utilizando un clasificador de votación *soft* o *hard*.

# %%
# tu código aquí

# %% [markdown]
# ## 4. *Stacking*
#
# Ejecuta los clasificadores individuales del ejercicio anterior para hacer predicciones sobre el conjunto de validación, y crea un nuevo conjunto de entrenamiento con las predicciones resultantes: cada instancia de entrenamiento es un vector que contiene el conjunto de predicciones de todos tus clasificadores para una imagen, y el objetivo es la clase de la imagen. Entrena un clasificador en este nuevo conjunto de entrenamiento.

# %%
# tu código aquí

# %% [markdown]
# ¡Felicidades, acabas de entrenar un mezclador (*blender*), y junto con los clasificadores forman un conjunto de *stacking*! Ahora evaluemos el modelo en el conjunto de prueba. Para cada imagen en el conjunto de prueba, haz predicciones con todos tus clasificadores, luego alimenta las predicciones al mezclador para obtener las predicciones del conjunto. ¿Cómo se compara con el clasificador de votación que entrenaste anteriormente?

# %%
# tu código aquí
