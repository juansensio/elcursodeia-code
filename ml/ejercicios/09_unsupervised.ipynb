# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/juansensio/elcursodeia-code/blob/master/ml/ejercicios/09_unsupervised.ipynb)

# %% [markdown]
# # Ejercicio: Aprendizaje semi-supervisado y *Active Learning* el dataset MNIST

# %% [markdown]
# ## 1. Descarga MNIST

# %% [markdown]
# ## 2. Entrena un clasificador con solo 50 etiquetas
#
# Un caso de uso para el clustering es en el aprendizaje semi-supervisado, cuando tenemos muchas instancias no etiquetadas y muy pocas instancias etiquetadas.

# %% [markdown]
# ## 3. Usa K-Means para agrupar datos
#
# Agrupa el conjunto de entrenamiento en 50 clusters.

# %% [markdown]
# ## 4. Visualiza las imágenes representativas
#
# Para cada clúster, encuentra la imagen más cercana al centroide. Llamaremos a estas imágenes las imágenes representativas.

# %% [markdown]
# ## 5. Etiqueta las imágenes representativas
#
# Etiqueta manualmente cada imagen representativa.

# %% [markdown]
# ## 6. Entrena un clasificador con las imágenes representativas

# %% [markdown]
# ## 7. Propagación de etiquetas
#
# Propaga las etiquetas de las imágenes representativas al resto de las imágenes en el mismo clúster y entrena el clasificador nuevamente.

# %% [markdown]
# ## 8. Propagación de etiquetas más inteligente
#
# Propaga las etiquetas al percentil 20 más cercano al centroide.

# %% [markdown]
# ## 9. Active learning
#
# Etiqueta manualmente las instancias sobre las que el clasificador está menos seguro (idealmente de cada clúster) y entrena un nuevo clasificador.
