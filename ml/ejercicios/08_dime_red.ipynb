# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/juansensio/elcursodeia-code/blob/master/ml/ejercicios/08_dime_red.ipynb)

# %% [markdown]
# # Ejercicio: Experimenta con reducción de la dimensionalidad en el dataset MNIST

# %% [markdown]
# ## 1. Descarga MNIST
#
# Recuerda dividirlo en un conjunto de entrenamiento y un conjunto de test (toma las primeras 60,000 instancias para entrenamiento y las 10,000 restantes para prueba).

# %% [markdown]
# ## 2. Entrena un clasificador Random Forest
#
# Entrena un clasificador Random Forest en el conjunto de datos y mide cuánto tiempo tarda, luego evalúa el modelo resultante en el conjunto de test.

# %% [markdown]
# ## 3. Usa PCA
#
# Usa PCA para reducir la dimensionalidad del conjunto de datos, con una proporción de varianza explicada del 95%.

# %% [markdown]
# ## 4. Entrena otra vez
#
# Entrena un nuevo clasificador Random Forest en el conjunto de datos reducido y mide cuánto tiempo tarda. ¿Fue el entrenamiento mucho más rápido? ¿Cómo se compara con el clasificador anterior?

# %% [markdown]
# La reducción de dimensionalidad no siempre conduce a un tiempo de entrenamiento más rápido: depende del conjunto de datos, el modelo y el algoritmo de entrenamiento. Intenta usar un clasificador softmax en lugar de un clasificador random forest.

# %% [markdown]
# ## 5. Usa t-SNE para visualizar los datos
#
# Usa t-SNE para reducir el conjunto de datos MNIST a dos dimensiones y visualiza el resultado usando Matplotlib. Puedes usar un diagrama de dispersión con 10 colores diferentes para representar la clase objetivo de cada imagen. La reducción de dimensionalidad en las 60,000 imágenes completas lleva mucho tiempo, así que hazlo solo con un subconjunto aleatorio de 10,000 imágenes.

# %%
m = 10000
idx = np.random.permutation(60000)[:m]
X = mnist['data'].values[idx]
y = mnist['target'].values[idx]

# %% [markdown]
# ## 5. Usa PCA para acelerar t-SNE
#
# Crea una *pipeline* donde se aplique PCA antes de t-SNE. ¿Es más rápido? ¿Hay pérdida de rendimiento?
